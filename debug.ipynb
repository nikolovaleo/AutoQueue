# %%
import pandas as pd
import numpy as np

# %%
df_viernes = pd.read_excel("./data/Viernes New Master Data for Pizarra.xlsx")
df_lunes = pd.read_excel("./data/Lunes New Master Data for Pizarra.xlsx")

# %%
df_viernes.dtypes
df_lunes.dtypes
# Out:
# filter                      object
# type                        object
# Number                      object
# Workgroup                   object
# Owner Name                  object
# Call State                  object
# Open Date           datetime64[ns]
# Open Year                    int64
# Open Month                   int64
# Open Day                     int64
# Closed Date         datetime64[ns]
# Closed Year                float64
# Closed Month               float64
# Closed Day                 float64
# Call Minutes               float64
# Days Open                    int64
# Parked                      object
# Support Level               object
# Operation Impact            object
# Submitted Via               object
# Severity High               object
# dtype: object

# %%
df_viernes.head()
# Out:
#                                  filter     type        Number  \
# 0  48b54f6a-8232-4057-ae01-3c1932bb05f3  CtsCall  NC-2303-6030
# 1  7219ed3a-760a-4b40-99e4-0bf9c6220725  CtsCall  NC-2303-5992
# 2  888b25f6-e039-4777-aebd-0c76cef52372  CtsCall  NC-2303-5981
# 3  b145af48-6da0-4be5-93f8-983272dc1fd8  CtsCall  NC-2303-5969
# 4  b5817a48-df74-4fd4-a0df-848a9adc8328  CtsCall  NC-2303-5964
#
#          Workgroup                               Owner Name Call State  \
# 0  PWS-TECHSUPPORT     Castro Fajardo, Ana [AUTOSOL/PWS/CR]       Open
# 1  PWS-TECHSUPPORT          Mora, Andres [AUTOSOL/PWS/CORI]     Closed
# 2  PWS-TECHSUPPORT  Villarreal, Emmanuel [AUTOSOL/PWS/CORI]       Open
# 3  PWS-TECHSUPPORT     Castro Fajardo, Ana [AUTOSOL/PWS/CR]       Open
# 4  PWS-TECHSUPPORT       Urena, Leonardo [AUTOSOL/PWS/CORI]     Closed
#
#             Open Date  Open Year  Open Month  Open Day  ... Closed Year  \
# 0 2023-09-07 22:51:09       2023           9         7  ...         NaN
# ...

# %%
df_lunes.head()
# Out:
#                                  filter     type        Number  \
# 0  9fc64043-e39d-4ef9-bdb0-3f4588498bbb  CtsCall  NC-2303-6297
# 1  b8333090-2838-4b68-9cd2-604ac74fd9c3  CtsCall  NC-2303-6296
# 2  4a403d93-893f-4173-92c5-90b095da7b48  CtsCall  NC-2303-6275
# 3  43ff7162-06ce-4196-9a89-57562a9201bc  CtsCall  NC-2303-6207
# 4  3260fc98-2d8f-4bf0-ab3e-9d75b2f4c166  CtsCall  NC-2303-6197
#
#          Workgroup                           Owner Name Call State  \
# 0  PWS-ENG-SUPPORT    Brenes, Jaime [EMR/SYSS/PWS/GUAC]       Open
# 1  PWS-ENG-SUPPORT    Brenes, Jaime [EMR/SYSS/PWS/GUAC]       Open
# 2  PWS-TECHSUPPORT      Brenes, Jose [AUTOSOL/PWS/CORI]       Open
# 3  PWS-ENG-SUPPORT  Chacon, Esteban [EMR/SYSS/PWS/GUAC]       Open
# 4  PWS-TECHSUPPORT   Urena, Leonardo [AUTOSOL/PWS/CORI]       Open
#
#             Open Date  Open Year  Open Month  Open Day  ... Closed Year  \
# 0 2023-09-11 11:24:55       2023           9        11  ...         NaN
# ...

# %%
colum = ["Number",	"Workgroup",	"Owner Name",	"Call State",	"Open Date",	"Open Year",	"Open Month",	"Open Day",	"Closed Date",	"Closed Year",	"Closed Month",	"Closed Day",	"Call Minutes",	"Days Open",	"Parked",	"Support Level",	"Operation Impact",	"Submitted Via",	"Severity High"]
idx = colum[18]


case = 0

# %%
print(type(df_viernes.loc[case,idx]))
V = df_viernes.loc[case,idx]
df_viernes.loc[case ,idx]
# Out:
# <class 'str'>
# 'C4'

# %%
print(type(df_lunes.loc[case + 16,idx]))
L = df_lunes.loc[case + 16,idx]
df_lunes.loc[case + 16,idx]
# Out:
# <class 'str'>
# 'C4'

# %%
V == L
# Out:
# True
